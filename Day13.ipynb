# %% [markdown]
# <a href="https://colab.research.google.com/github/NagillaSannidhi/python/blob/main/Day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
k=[4,2.5678,9,87.9999,40,'india']
k
# Out:
# [4, 2.5678, 9, 87.9999, 40, 'india']

# %%
pd.Series(k)
# Out:
# 0          4
# 1     2.5678
# 2          9
# 3    87.9999
# 4         40
# 5      india
# dtype: object

# %%
k=[4,2.5678,9,87.9999,40,]

# %%
k
# Out:
# [4, 2.5678, 9, 87.9999, 40]

# %%
pd.Series(k)
# Out:
# 0     4.0000
# 1     2.5678
# 2     9.0000
# 3    87.9999
# 4    40.0000
# dtype: float64

# %%
a=np.random.randint(20,50,(5,4))
a
# Out:
# array([[31, 46, 31, 25],
#        [46, 27, 42, 41],
#        [25, 48, 30, 20],
#        [47, 23, 25, 31],
#        [24, 24, 48, 32]])

# %%
a.ndim
# Out:
# 2

# %%
a=np.random.randint(20,50,15)

pd.Series(a)
# Out:
# 0     40
# 1     33
# 2     27
# 3     33
# 4     31
# 5     26
# 6     22
# 7     25
# 8     45
# 9     20
# 10    36
# 11    36
# 12    44
# 13    34
# 14    38
# dtype: int64

# %%
s=pd.Series(a)
s
# Out:
# 0     40
# 1     33
# 2     27
# 3     33
# 4     31
# 5     26
# 6     22
# 7     25
# 8     45
# 9     20
# 10    36
# 11    36
# 12    44
# 13    34
# 14    38
# dtype: int64

# %%
s[0]
# Out:
# 40

# %%
s[8]
# Out:
# 45

# %%
s[4:10]
# Out:
# 4    31
# 5    26
# 6    22
# 7    25
# 8    45
# 9    20
# dtype: int64

# %%
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[127, 170, 189, 158, 134],
#        [188, 172, 119, 131, 194],
#        [186, 184, 180, 102, 123],
#        [114, 143, 136, 195, 199],
#        [188, 103, 184, 187, 144],
#        [177, 111, 124, 183, 189]])

# %%
b.ndim
# Out:
# 2

# %%
pd.DataFrame(b)
# Out:
#      0    1    2    3    4
# 0  127  170  189  158  134
# 1  188  172  119  131  194
# 2  186  184  180  102  123
# 3  114  143  136  195  199
# 4  188  103  184  187  144
# 5  177  111  124  183  189

# %%
df=pd.DataFrame(b)
df
# Out:
#      0    1    2    3    4
# 0  127  170  189  158  134
# 1  188  172  119  131  194
# 2  186  184  180  102  123
# 3  114  143  136  195  199
# 4  188  103  184  187  144
# 5  177  111  124  183  189

# %%
df=pd.DataFrame(b,columns=['roll','name','age','code','country'])
df
# Out:
#    roll  name  age  code  country
# 0   127   170  189   158      134
# 1   188   172  119   131      194
# 2   186   184  180   102      123
# 3   114   143  136   195      199
# 4   188   103  184   187      144
# 5   177   111  124   183      189

# %%
df=pd.DataFrame(b,columns=['roll','name','age','code','country'],index=['nafees','pooji','navanitha','meghana','nikhitha','sannidhi'])
df
# Out:
#            roll  name  age  code  country
# nafees      127   170  189   158      134
# pooji       188   172  119   131      194
# navanitha   186   184  180   102      123
# meghana     114   143  136   195      199
# nikhitha    188   103  184   187      144
# sannidhi    177   111  124   183      189

# %%
df.iloc[3]
# Out:
# roll       114
# name       143
# age        136
# code       195
# country    199
# Name: meghana, dtype: int64

# %%
df.iloc[5]
# Out:
# roll       177
# name       111
# age        124
# code       183
# country    189
# Name: sannidhi, dtype: int64

# %%
df.loc['nafees']
# Out:
# roll       127
# name       170
# age        189
# code       158
# country    134
# Name: nafees, dtype: int64

# %%
df.iloc[2,4]
# Out:
# 123

# %%
df.loc['nikhitha',['roll','code']]
# Out:
# roll    188
# code    187
# Name: nikhitha, dtype: int64

# %%
df.iloc[3,2:4]
# Out:
# age     136
# code    195
# Name: meghana, dtype: int64

# %%
df.iloc[[1,3,4]]
# Out:
#           roll  name  age  code  country
# pooji      188   172  119   131      194
# meghana    114   143  136   195      199
# nikhitha   188   103  184   187      144

# %%
df.iloc[[0,5]]
# Out:
#           roll  name  age  code  country
# nafees     127   170  189   158      134
# sannidhi   177   111  124   183      189

# %%
df
# Out:
#            roll  name  age  code  country
# nafees      127   170  189   158      134
# pooji       188   172  119   131      194
# navanitha   186   184  180   102      123
# meghana     114   143  136   195      199
# nikhitha    188   103  184   187      144
# sannidhi    177   111  124   183      189

# %%
df.age
# Out:
# nafees       189
# pooji        119
# navanitha    180
# meghana      136
# nikhitha     184
# sannidhi     124
# Name: age, dtype: int64

# %%
df['age']
# Out:
# nafees       189
# pooji        119
# navanitha    180
# meghana      136
# nikhitha     184
# sannidhi     124
# Name: age, dtype: int64

# %%
df[['age','country']]
# Out:
#            age  country
# nafees     189      134
# pooji      119      194
# navanitha  180      123
# meghana    136      199
# nikhitha   184      144
# sannidhi   124      189

# %%
df.loc[['nafees','nikhitha'],['roll','code']]
# Out:
#           roll  code
# nafees     127   158
# nikhitha   188   187

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.load_dataset('dots')
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1=sns.load_dataset('titanic')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df1.shape
# Out:
# (891, 15)
